# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaLesyk/numerical-methods-of-programming/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторна робота №5
# Виконало студентка ФІТ 3-14
# Лесик Анна

# %%
#Побудова графіка функції
import numpy as np
import matplotlib.pyplot as plt

# область значень для x та y
x_min, x_max = -1, 2
y_min, y_max = -4, 1
step = 0.001

# створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step),
                   np.arange(y_min, y_max, step))

# рівняння системи
eq1 = np.cos(y + 0.5) + x - 0.8
eq2 = np.sin(x) - 2*y - 1.6

# створюємо графік
fig, ax = plt.subplots(figsize=(5, 5))

# додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')
plt.grid(True)

# показуємо графік
plt.show()


#Розв'язок системи рівнянь методом простої ітерації
x0 = 0.8
y0 = -1.2
delta = 0.1

def f1(y):
    return math.cos(y + 0.5) - 0.8 #задаємо функції
def f2 (x):
    return 1/2*math.sin(x) -0.8 #задаємо функції

def iter (x,y,e):
    xn = x
    yn = y
    xn1 = f2(x)
    yn1 = f1(y)
    n = 1
    while ((abs(xn1-xn)>=e) & (abs(yn1-yn) >=e)):
        xn = xn1
        yn = yn1
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
    print ('Simple iteration:')
    print ('x=', xn, '\ny=',yn,'\nThe amount of iteration = ',n)
iter(x0,y0,0.0001)

def f3(x): #Задаємо функцію для перевірки
    return math.cos(x[0] + 0.5) + x[1] - 0.8, math.sin(x[0]) - 2*x[0] - 1.6
s = optimize.root(f3, [0.,0.], method = 'hybr') #Перевірка розв*язку      #Відповіді мають співпасти
print ('Chek',s.x)
# Out:
# Simple iteration:
# x= -0.7117721149110305
# y= 0.17771382708903605
# The amount of iteration =  9
# Chek [-1.27884153  0.08827221]
